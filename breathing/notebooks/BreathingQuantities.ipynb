# %%
import pynbody
import glob

import numpy as np

import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../util/')
from util_os import util_os
from util_galaxies import util_galaxies

import scipy.optimize as opt

import random

# %% [markdown]
# ## Get Our Galaxies

# %%
currentGals = util_os.getGalaxies()[0]

# %% [markdown]
# ## Lookback Time and Redshift

# %%
gal = currentGals[1]
cdmFile = util_os.getfilepath_cdm(gal,0)

# tmp 
#cdmFile = '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r468.romulus25.3072g1HsbBH/'
#cdmFile += 'r468.romulus25.3072g1HsbBH.003936/r468.romulus25.3072g1HsbBH.003936'

sCDM = pynbody.load(cdmFile)
sCDM.physical_units()

vdisp = sCDM.g['v_disp']

hCDM = sCDM.halos(write_fpos=False)[1]

pynbody.analysis.angmom.faceon(hCDM)

cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
sCDM['pos'] -= cen_pot

# %%
len(sCDM.s['mass']) + len(sCDM.g['mass']) + len(sCDM.d['mass'])
# Out:
# 25805790

# %%
#sCDM.properties['boxsize'] = 2.5e4

# %%
sCDM.properties['boxsize']
# Out:
# Unit("2.50e+04 kpc")

# %%
pynbody.analysis.cosmology.age(sCDM)
# Out:
# 13.800820457603765

# %% [markdown]
# ## Half Mass Radius (Stellar Mass)
#
# Call the function twice for an accurate measurement. First with coarse steps and low accuracy and then again with finer steps and accuracy using 90% of the first measurement as a starting point

# %%
# input: a simulation 
# output: half mass radius of that simulation
def halfMassRadius(sim, startR, incBy, acc):
    pRadii = np.array(sim.s['r'])
    pMass = np.array(sim.s['mass'])
    mTot = sum(pMass)
    
    # start at 5 kpc and increment
    r = startR-incBy
    hm = mTot
    while(hm < (0.50-acc)*mTot or hm > (0.5+acc)*mTot):
        r += incBy
        hm = sum(pMass[pRadii < r])
        
        if (r>max(pRadii)):
            return -1
        
    return r

# %%
halfMassRadius(sCDM, 0, 1, 0.1)
# Out:
# 3

# %%
halfMassRadius(sCDM,2,0.05,0.01)
# Out:
# 2.849999999999997

# %%
def halfMassRadius_bisect(sim, outerR, acc):
    innerLim = 0.0
    outerLim = outerR
    guessR = 0.0

    pRadii = np.array(sim.s['r'])
    pMass = np.array(sim.s['mass'])
    mTot = sum(pMass)

    r = outerR
    hm = mTot
    while(hm < (0.50-acc)*mTot or hm > (0.5+acc)*mTot):
        if hm > 0.5*mTot:
            outerLim = r
            r = innerLim + (outerLim-innerLim)/2
        if hm < 0.5*mTot:
            innerLim = r
            r = innerLim + (outerLim-innerLim)/2
        hm = sum(pMass[pRadii < r])

    return r

# %%
halfMassRadius_bisect(sCDM,100,0.001)
# Out:
# 2.9052734375

# %%
sCDM.s['vel']
# Out:
# SimArray([[  65.63792589,   13.30896193,  -43.46616412],
#           [  14.4127238 ,   -5.42542935,  -21.1465444 ],
#           [  30.21906607,    5.52502769,   16.57051852],
#           ...,
#           [-107.88541766,    8.87287087,    7.71992681],
#           [ -21.97960799,  -86.69778089,   -4.84913249],
#           [ -22.97036113,  -78.56799526,   -2.0968231 ]], 'km s**-1')

# %% [markdown]
# ## Manual V disp

# %%
def compute_vdisp(velocities, masses):
    center_of_mass_velocity = np.sum(velocities * masses[:, None], axis=0) / np.sum(masses)
    velocity_differences = velocities - center_of_mass_velocity
    velocity_differences_squared = np.sum(velocity_differences**2, axis=1)
    mass_weighted_dispersion = np.sqrt(np.sum(velocity_differences_squared * masses) / np.sum(masses))
    #return mass_weighted_dispersion
    return velocity_differences

# %%
mask = sCDM.s['age'].in_units('Myr')<10
compute_vdisp(sCDM.s['vel'][mask], sCDM.s['mass'][mask])
# Out:
# SimArray(66.98288933, 'km s**-1')

# %% [markdown]
# ### V disp of cold gas (T < 1000K)

# %%
coldgasVel = sCDM.g['vel']
coldgasMass= sCDM.g['mass']

mask = sCDM.g['temp']<=1000

coldgasVel = coldgasVel[mask]
coldgasMass= coldgasMass[mask]

compute_vdisp(coldgasVel, coldgasMass)
# Out:
# SimArray(57.04085245, 'km s**-1')

# %%
sCDM.g['temp'][sCDM.g['temp']<=1000]
# Out:
# SimArray([212.44827271, 428.86395264, 957.68774414, ...,  38.43917084,
#            38.46290588,  38.44889832], 'K')

# %% [markdown]
# ## v disp as std dev of radial velocity

# %%
# desired params 
gal = currentGals[15]
tsidx = 0

# get to sim file 
baseDir = '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms'
galDir = baseDir + '/r' + str(gal)+'.romulus25.3072g1HsbBH'

timesteps = glob.glob(galDir+'/r*.romulus25.3072g1HsbBH.0*')
timesteps.sort(reverse=True)

tsnum = timesteps[tsidx][-4:]
simfile = glob.glob(timesteps[tsidx]+'/r'+str(gal)+'*.00'+tsnum)

# load simfile 
sCDM = pynbody.load(simfile[0])
sCDM.physical_units()

# center 
hCDM = -1
try:
    hCDM = sCDM.halos(write_fpos=False)[1]
except:
    # center manually if missing halo; taken from pynbody source code
    #print('HNF for halo ' + str(gal) + ', timestep '+str(tstepnumber))
    i = sCDM['phi'].argmin()
    cen_pot = sCDM['pos'][i].copy()
    sCDM['pos'] -= cen_pot
else:
    hCDM = sCDM.halos(write_fpos=False)[1]
    cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
    sCDM['pos'] -= cen_pot

# %%
mask = sCDM.s['age'].in_units('Myr')<10
vr = np.linalg.norm(sCDM.s['vel'][mask], axis=1)
plt.hist(vr, density=True, bins=40);
print(np.std(vr))
# Out:
# 36.61407101860485

# %% [markdown]
# ## Mass weighted vdisp as a func of radius vs pynbody vdisp as a func of radius

# %%
mask = sCDM.s['age'].in_units('Myr')<10

positions = sCDM.s['pos'][mask]
velocities = sCDM.s['vel'][mask]
masses = sCDM.s['mass'][mask]
rads = sCDM.s['r'][mask]

vdisp_p = sCDM.s['v_disp'][mask]
vdisp_m = np.linalg.norm(compute_vdisp(velocities, masses), axis=1)
vdisp_r = abs(sCDM.s['vr'][mask])

plt.scatter(rads, vdisp_p, s=2)
plt.scatter(rads, vdisp_m, s=2)
plt.scatter(rads, vdisp_r, s=2)

plt.legend(['pynbody', 'yifei', 'radial'])

# %%
np.std(vdisp_r)
# Out:
# SimArray(31.83992167, 'km s**-1')

# %%
np.median(vdisp_p)
# Out:
# SimArray(34.92601009, 'km s**-1')

# %%
np.std(vdisp_m)
# Out:
# 14.128832969094422

# %% [markdown]
# ## Line of Sight Vdisp

# %%
fCDM = util_os.getfilepath_cdm(442, 0)

sCDM = pynbody.load(fCDM)
sCDM.physical_units()

hCDM = sCDM.halos()[1]

starpos = hCDM.s['pos']
starvels = hCDM.s['vel']
starmasses = hCDM.s['mass']

youngstarmask = hCDM.s['age'].in_units('Myr')<10
youngstarpos = starpos[youngstarmask]
youngstarvels = starvels[youngstarmask]
youngstarmasses = starmasses[youngstarmask]

# center by dm mass
mtot = hCDM.s['mass'].sum()
cen = np.sum(hCDM.s['mass'] * hCDM.s['pos'].transpose(), axis=1) / mtot
cen.units = hCDM.s['pos'].units

rhm = util_galaxies.compute_massRadius(hCDM.s['pos'], starmasses, 1000, 0.01)

# %%
a = np.array([[1,2,3], [4,5,6]])
a*a
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %%
def los_vdisp(vel_all, mass_all, pos_t, vel_t, hmr, weights=[]):
    R = 10*hmr

    if len(weights == 0):
        weights = np.ones(len(vel_t))

    # subtract systematic/CoM velocity
    v_CoM = np.sum(vel_all * mass_all[:, None], axis=0) / np.sum(mass_all)
    vdiffs = np.array(vel_t - v_CoM)
    #vdiffs_mag = np.linalg.norm(vdiffs, axis=1)

    allvdisps = []
    for i in range(100):
        # select viewing location
        theta = random.uniform(0, np.pi)
        phi = random.uniform(0, 2*np.pi)

        x = R*np.sin(theta)*np.cos(phi)
        y = R*np.sin(theta)*np.sin(phi)
        z = R*np.cos(theta)

        # unit vector from particle position to observation point
        a = np.array([x,y,z]-pos_t)
        a = a/np.linalg.norm(a, axis=1)[:,None]
        # projection of velocity along vector a
        vel_los = np.linalg.norm(vdiffs*a, axis=1)

        weightedstd = np.sum( ((vel_los-np.mean(vel_los))**2) * weights)
        weightedstd = weightedstd/np.sum(weights)
        weightedstd = np.sqrt(weightedstd)

        allvdisps.append(weightedstd)

    return np.median(allvdisps)

# %%
los_vdisp(starvels, starmasses, youngstarpos, youngstarvels, rhm, youngstarmasses)
# Out:
# 13.658323941798205

# %% [markdown]
# ## sigma_gas
# From Hirtenstein (2019): HII regions within 100 PC of young stars (10MYR); calculate density weghted dispersion. Median over 100 lines of sight

# %%
sCDM.all_keys()
# Out:
# ['HII',
#  'HeIII',
#  'ne',
#  'hetot',
#  'hydrogen',
#  'feh',
#  'oxh',
#  'ofe',
#  'mgfe',
#  'nefe',
#  'sife',
#  'c_s',
#  'c_s_turb',
#  'mjeans',
#  'mjeans_turb',
#  'ljeans',
#  'ljeans_turb',
#  'r',
#  'rxy',
#  'vr',
#  'v2',
#  'vt',
#  'ke',
#  'te',
#  'j',
#  'j2',
#  'jz',
#  'vrxy',
#  'vcxy',
#  'vphi',
#  'vtheta',
#  'v_mean',
#  'v_disp',
#  'v_curl',
#  'vorticity',
#  'v_div',
#  'age',
#  'u_mag',
#  'u_lum_den',
#  'b_mag',
#  'b_lum_den',
#  'v_mag',
#  'v_lum_den',
#  'r_mag',
#  'r_lum_den',
#  'i_mag',
#  'i_lum_den',
#  'j_mag',
#  'j_lum_den',
#  'h_mag',
#  'h_lum_den',
#  'k_mag',
#  'k_lum_den',
#  'U_mag',
#  'U_lum_den',
#  'B_mag',
#  'B_lum_den',
#  'V_mag',
#  'V_lum_den',
#  'R_mag',
#  'R_lum_den',
#  'I_mag',
#  'I_lum_den',
#  'J_mag',
#  'J_lum_den',
#  'H_mag',
#  'H_lum_den',
#  'K_mag',
#  'K_lum_den',
#  'theta',
#  'alt',
#  'az',
#  'cs',
#  'mu',
#  'p',
#  'u',
#  'temp',
#  'zeldovich_offset',
#  'aform',
#  'tform',
#  'iord_argsort',
#  'smooth',
#  'rho',
#  'pos',
#  'mass',
#  'vel',
#  'amiga.grp',
#  'eps',
#  'phi']

# %%
sCDM.g['hydrogen']
# Out:
# SimArray([0.764     , 0.764     , 0.764     , ..., 0.72890668, 0.73387738,
#           0.73172798])

# %%
youngstarPos = sCDM.s['pos'][sCDM.s['age'].in_units('Myr')<10]
HIIpos = sCDM.g['pos']

# %%
len(youngstarPos)
# Out:
# 2238

# %%
# %%time
# gas within 100 pc of first young star 

indexes = []

for x,pos in enumerate(youngstarPos[:]):
    mask = np.linalg.norm(sCDM.g['pos']-pos,axis=1)<0.1
    
    for i in np.where(mask==True)[0]:
        indexes.append(i)
        
    if x%250==0: print(x)
# Out:
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# CPU times: user 6min 36s, sys: 2min 29s, total: 9min 5s
# Wall time: 9min 5s

# %%
arr = np.array([1,2,3,4,5])
mask = [0,0,1]
arr[mask]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 arr = np.array([1,2,3,4,5])
#       2 mask = [0,0,1]
#       3 arr[mask]
#
# NameError: name 'np' is not defined

# %%
# center positions 
mtot = np.sum(sCDM.s['mass'])
cen = np.sum(sCDM.s['mass'] * sCDM.s['pos'].transpose(),
                     axis=1) / mtot

gaspos_sel = sCDM.g['pos'][indexes]-cen
gasmass_sel = (sCDM.g['mass']*sCDM.g['hydrogen'])[indexes]
gasvel_sel = sCDM.g['vel'][indexes]

util_galaxies.compute_vdisp_los(sCDM.g['vel'], sCDM.g['mass'], gaspos_sel, gasvel_sel, 5, gasmass_sel)
# Out:
# 12.887542749790263

# %%
pynbody.snapshot.tipsy.HII(sCDM.g)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1919, in FamilySubSnap._get_array(self, name, index, always_writable)
#    1918 try:
# -> 1919     return SubSnap._get_array(self, name, index, always_writable)
#    1920 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1662, in SubSnap._get_array(self, name, index, always_writable)
#    1661 else:
# -> 1662     ret = self.base._get_array(name, util.concatenate_indexing(
#    1663         self._slice, index), always_writable)
#    1664     ret.family = self._unifamily
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1196, in SimSnap._get_array(self, name, index, always_writable)
#    1189 """Get the array of the specified *name*, optionally
#    1190 for only the particles specified by *index*.
#    1191
#    1192 If *always_writable* is True, the returned array is
#    1193 writable. Otherwise, it is still normally writable, but
#    1194 not if the array is flagged as derived by the framework."""
# -> 1196 x = self._arrays[name]
#    1197 if x.derived and not always_writable:
#
# KeyError: 'HI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1224, in SimSnap._get_family_array(self, name, fam, index, always_writable)
#    1223 try:
# -> 1224     x = self._family_arrays[name][fam]
#    1225 except KeyError:
#
# KeyError: 'HI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/tipsy.py:986, in HII(sim)
#     985 try:
# --> 986     return Y_H - sim["HI"] - 2 * sim["H2"]
#     987 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:258, in SimSnap.__getitem__(self, i)
#     257 if isinstance(i, str):
# --> 258     return self._get_array_with_lazy_actions(i)
#     259 elif isinstance(i, slice):
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:360, in SimSnap._get_array_with_lazy_actions(self, name)
#     358         self.__derive_if_required(name)
# --> 360 return self._get_array(name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1921, in FamilySubSnap._get_array(self, name, index, always_writable)
#    1920 except KeyError:
# -> 1921     return self.base._get_family_array(name, self._unifamily, index, always_writable)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1226, in SimSnap._get_family_array(self, name, fam, index, always_writable)
#    1225 except KeyError:
# -> 1226     raise KeyError("No array " + name + " for family " + fam.name)
#    1228 if x.derived and not always_writable:
#
# KeyError: 'No array HI for family gas'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1919, in FamilySubSnap._get_array(self, name, index, always_writable)
#    1918 try:
# -> 1919     return SubSnap._get_array(self, name, index, always_writable)
#    1920 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1662, in SubSnap._get_array(self, name, index, always_writable)
#    1661 else:
# -> 1662     ret = self.base._get_array(name, util.concatenate_indexing(
#    1663         self._slice, index), always_writable)
#    1664     ret.family = self._unifamily
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1196, in SimSnap._get_array(self, name, index, always_writable)
#    1189 """Get the array of the specified *name*, optionally
#    1190 for only the particles specified by *index*.
#    1191
#    1192 If *always_writable* is True, the returned array is
#    1193 writable. Otherwise, it is still normally writable, but
#    1194 not if the array is flagged as derived by the framework."""
# -> 1196 x = self._arrays[name]
#    1197 if x.derived and not always_writable:
#
# KeyError: 'HI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1224, in SimSnap._get_family_array(self, name, fam, index, always_writable)
#    1223 try:
# -> 1224     x = self._family_arrays[name][fam]
#    1225 except KeyError:
#
# KeyError: 'HI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 pynbody.snapshot.tipsy.HII(sCDM.g)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/tipsy.py:988, in HII(sim)
#     986     return Y_H - sim["HI"] - 2 * sim["H2"]
#     987 except KeyError:
# --> 988     return Y_H - sim["HI"]
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:258, in SimSnap.__getitem__(self, i)
#     254 """Return either a specific array or a subview of this simulation. See
#     255 the class documentation (:class:`SimSnap`) for more information."""
#     257 if isinstance(i, str):
# --> 258     return self._get_array_with_lazy_actions(i)
#     259 elif isinstance(i, slice):
#     260     return SubSnap(self, i)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:360, in SimSnap._get_array_with_lazy_actions(self, name)
#     357     if not self.lazy_derive_off:
#     358         self.__derive_if_required(name)
# --> 360 return self._get_array(name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1921, in FamilySubSnap._get_array(self, name, index, always_writable)
#    1919     return SubSnap._get_array(self, name, index, always_writable)
#    1920 except KeyError:
# -> 1921     return self.base._get_family_array(name, self._unifamily, index, always_writable)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1226, in SimSnap._get_family_array(self, name, fam, index, always_writable)
#    1224     x = self._family_arrays[name][fam]
#    1225 except KeyError:
# -> 1226     raise KeyError("No array " + name + " for family " + fam.name)
#    1228 if x.derived and not always_writable:
#    1229     x = x.view()
#
# KeyError: 'No array HI for family gas'

# %%
# contour to find HII regions
x = sCDM.g['pos'][:,0]
y = sCDM.g['pos'][:,1]
z = sCDM.g['pos'][:,2]

poslim = 1000

hii = sCDM.g['HII'][abs(x)<poslim]
z = z[abs(x)<poslim]
y = y[abs(x)<poslim]
x = x[abs(x)<poslim]

hii = hii[abs(y)<poslim]
z = z[abs(y)<poslim]
x = x[abs(y)<poslim]
y = y[abs(y)<poslim]

hii = hii[abs(z)<poslim]
x = x[abs(z)<poslim]
y = y[abs(z)<poslim]
z = z[abs(z)<poslim]

trc = plt.tricontour(x,y,hii)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 23
#      20 y = y[abs(z)<poslim]
#      21 z = z[abs(z)<poslim]
# ---> 23 trc = plt.tricontour(x,y,hii)
#      24 plt.colorbar()
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2936, in tricontour(*args, **kwargs)
#    2934 @_copy_docstring_and_deprecators(Axes.tricontour)
#    2935 def tricontour(*args, **kwargs):
# -> 2936     __ret = gca().tricontour(*args, **kwargs)
#    2937     if __ret._A is not None: sci(__ret)  # noqa
#    2938     return __ret
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/tricontour.py:241, in tricontour(ax, *args, **kwargs)
#     218 """
#     219 %(_tricontour_doc)s
#     220
#    (...)
#     238     number of contour levels it will be repeated as necessary.
#     239 """
#     240 kwargs['filled'] = False
# --> 241 return TriContourSet(ax, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/tricontour.py:29, in TriContourSet.__init__(self, ax, *args, **kwargs)
#      19 def __init__(self, ax, *args, **kwargs):
#      20     """
#      21     Draw triangular grid contour lines or filled regions,
#      22     depending on whether keyword arg *filled* is False
#    (...)
#      27     are described in the docstring of `~.Axes.tricontour`.
#      28     """
# ---> 29     super().__init__(ax, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/contour.py:794, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     790 if self.negative_linestyles is None:
#     791     self.negative_linestyles = \
#     792         mpl.rcParams['contour.negative_linestyle']
# --> 794 kwargs = self._process_args(*args, **kwargs)
#     795 self._process_levels()
#     797 self._extend_min = self.extend in ['min', 'both']
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/tricontour.py:45, in TriContourSet._process_args(self, *args, **kwargs)
#      43 else:
#      44     from matplotlib import _tri
# ---> 45     tri, z = self._contour_args(args, kwargs)
#      46     C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#      47     self._mins = [tri.x.min(), tri.y.min()]
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/tricontour.py:54, in TriContourSet._contour_args(self, args, kwargs)
#      53 def _contour_args(self, args, kwargs):
# ---> 54     tri, args, kwargs = Triangulation.get_from_args_and_kwargs(*args,
#      55                                                                **kwargs)
#      56     z = np.ma.asarray(args[0])
#      57     if z.shape != tri.x.shape:
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py:161, in Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#     158 else:
#     159     x, y, triangles, mask, args, kwargs = \
#     160         Triangulation._extract_triangulation_params(args, kwargs)
# --> 161     triangulation = Triangulation(x, y, triangles, mask)
#     162 return triangulation, args, kwargs
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py:58, in Triangulation.__init__(self, x, y, triangles, mask)
#      53 self.is_delaunay = False
#      55 if triangles is None:
#      56     # No triangulation specified, so use matplotlib._qhull to obtain
#      57     # Delaunay triangulation.
# ---> 58     self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      59     self.is_delaunay = True
#      60 else:
#      61     # Triangulation specified. Copy, since we may correct triangle
#      62     # orientation.
#
# KeyboardInterrupt:

# %%
# contour gas mass 
x = sCDM.g['pos'][:,0]
y = sCDM.g['pos'][:,1]
z = sCDM.g['pos'][:,2]

gmass = sCDM.g['mass']

plt.tricontour(x,y,gmass)
plt.colorbar()

# %%
fig = plt.figure(facecolor='w', figsize=(12,8))

hs = plt.hist(sCDM.g['HII'], density=False, stacked=True)
plt.ylabel('Quantity of Particles', fontsize=20)
plt.xlabel('Number of HII Ions Per Proton Mass', fontsize=20)
# Out:
# Text(0.5, 0, 'Number of HII Ions Per Proton Mass')

# %%
len(sCDM.g['pos'])
# Out:
# 6013100

# %%
gal = currentGals[0]
cdmFile = util.getfilepath(gal)[0]+ '/r'+str(gal)+'.romulus25.3072g1HsbBH.004096'

sCDM = pynbody.load(cdmFile)
sCDM.physical_units()

vdisp = sCDM.g['v_disp']

hCDM = sCDM.halos(write_fpos=False)[1]

pynbody.analysis.angmom.faceon(hCDM)

cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
sCDM['pos'] -= cen_pot

# %%
# want HII particles near stars

# take regions that are mostly HII 
HIIpos = sCDM.g['pos'].in_units('pc')

selectedHIIdisps = []
allHIIdisps = sCDM.g['vr']

# want regions within 100 pc of young (10 MYR) stars
youngStarPos = sCDM.s['pos'].in_units('pc')[sCDM.s['age'].in_units('Myr')<10]
for i,hii in enumerate(HIIpos[:]):
    distances = abs(youngStarPos - hii)
    distances = np.linalg.norm(distances, axis=1)
    
    # if close to a young star, calculate v disp for that particle
    if min(distances)<100:
        selectedHIIdisps.append(allHIIdisps[i])
    if i%500000==0: print(i)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000

# %%
len(selectedHIIdisps)
# Out:
# 142419

# %%
np.median(np.abs(selectedHIIdisps))
# Out:
# 11.452646856604877

# %%
np.median(vdisp)
# Out:
# SimArray(22.85070953, 'km s**-1')

# %%
# above didn't provide any particles
# let's just directly take v disp of HII dominated particles


hiimask = sCDM.g['HII']>0.75

# %%
gal = currentGals[1]
#cdmFile = util.getfilepath(gal)[0]+ '/r'+str(gal)+'.romulus25.3072g1HsbBH.004096'
cdmFile='/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r468.romulus25.3072g1HsbBH/'
cdmFile+='r468.romulus25.3072g1HsbBH.003936/r468.romulus25.3072g1HsbBH.003936'

sCDM = pynbody.load(cdmFile)
sCDM.physical_units()
hCDM = sCDM.halos(write_fpos=False)[1]

pynbody.analysis.angmom.faceon(hCDM)

cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
sCDM['pos'] -= cen_pot

hiimask = sCDM.g['HII']>0.75
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 8
#       6 sCDM = pynbody.load(cdmFile)
#       7 sCDM.physical_units()
# ----> 8 hCDM = sCDM.halos(write_fpos=False)[1]
#      10 pynbody.analysis.angmom.faceon(hCDM)
#      12 cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:788, in SimSnap.halos(self, *args, **kwargs)
#     785     except TypeError:
#     786         pass
# --> 788 raise RuntimeError("No halo catalogue found for %r" % str(self))
#
# RuntimeError: No halo catalogue found for '<SimSnap "/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r468.romulus25.3072g1HsbBH/r468.romulus25.3072g1HsbBH.003936/r468.romulus25.3072g1HsbBH.003936" len=25789729>'

# %%
sCDM.g['HII']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sCDM['HII']
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:258, in SimSnap.__getitem__(self, i)
#     254 """Return either a specific array or a subview of this simulation. See
#     255 the class documentation (:class:`SimSnap`) for more information."""
#     257 if isinstance(i, str):
# --> 258     return self._get_array_with_lazy_actions(i)
#     259 elif isinstance(i, slice):
#     260     return SubSnap(self, i)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:358, in SimSnap._get_array_with_lazy_actions(self, name)
#     356         self.__load_if_required(name)
#     357     if not self.lazy_derive_off:
# --> 358         self.__derive_if_required(name)
#     360 return self._get_array(name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:373, in SimSnap.__derive_if_required(self, name)
#     371 def __derive_if_required(self, name):
#     372     if name not in list(self.keys()):
# --> 373         self._derive_array(name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:1425, in SimSnap._derive_array(self, name, fam)
#    1423 with self.auto_propagate_off:
#    1424     if fam is None:
# -> 1425         result = fn(self)
#    1426         ndim = result.shape[-1] if len(
#    1427             result.shape) > 1 else 1
#    1428         self._create_array(
#    1429             name, ndim, dtype=result.dtype, derived=not fn.__stable__)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/tipsy.py:984, in HII(sim)
#     981 @TipsySnap.derived_quantity
#     982 def HII(sim):
#     983     """Number of HII ions per proton mass"""
# --> 984     Y_H, Y_He = _abundance_estimator(sim["metals"])
#     985     try:
#     986         return Y_H - sim["HI"] - 2 * sim["H2"]
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:258, in SimSnap.__getitem__(self, i)
#     254 """Return either a specific array or a subview of this simulation. See
#     255 the class documentation (:class:`SimSnap`) for more information."""
#     257 if isinstance(i, str):
# --> 258     return self._get_array_with_lazy_actions(i)
#     259 elif isinstance(i, slice):
#     260     return SubSnap(self, i)
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:352, in SimSnap._get_array_with_lazy_actions(self, name)
#     349     return self._get_array(name)
#     351 with self._dependency_tracker.calculating(name):
# --> 352     self.__resolve_obscuring_family_array(name)
#     354     if not self.lazy_off:
#     355         if not self.lazy_load_off:
#
# File ~/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/__init__.py:384, in SimSnap.__resolve_obscuring_family_array(self, name)
#     382 if name in self.family_keys():
#     383     in_fam, out_fam = self.__get_included_and_excluded_families_for_array(name)
# --> 384     raise KeyError("""{!r} is a family-level array for {}. To use it over the whole simulation you need either to delete it first, or create it separately for {}.""".format(
#     385         name, in_fam, out_fam))
#
# KeyError: "'metals' is a family-level array for [<Family gas>, <Family star>]. To use it over the whole simulation you need either to delete it first, or create it separately for [<Family dm>]."

# %%
plt.hist(sCDM.g['vr'][:10000])
# Out:
# (array([5.070e+02, 2.464e+03, 3.221e+03, 2.221e+03, 1.209e+03, 3.160e+02,
#         4.000e+01, 1.300e+01, 8.000e+00, 1.000e+00]),
#  array([-23.11633993,  -2.56619697,  17.98394599,  38.53408895,
#          59.08423192,  79.63437488, 100.18451784, 120.7346608 ,
#         141.28480376, 161.83494672, 182.38508968]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Need to Navigate the Folders of Emu
#
# * Given a halo number
# * navigate to each sim file and open it
# * acquire desired categories

# %%
sCDM.s['age'].in_units('Myr')
# Out:
# SimArray([1.35277645e+03, 1.34268115e+03, 1.34183987e+03, ...,
#           6.40484514e-03, 6.40484514e-03, 6.40484514e-03], 'Myr')

# %%
np.log10(sum(sCDM.g['mass']))
# Out:
# 10.267842295296536

# %%
sCDM.all_keys()
# Out:
# ['HII',
#  'HeIII',
#  'ne',
#  'hetot',
#  'hydrogen',
#  'feh',
#  'oxh',
#  'ofe',
#  'mgfe',
#  'nefe',
#  'sife',
#  'c_s',
#  'c_s_turb',
#  'mjeans',
#  'mjeans_turb',
#  'ljeans',
#  'ljeans_turb',
#  'r',
#  'rxy',
#  'vr',
#  'v2',
#  'vt',
#  'ke',
#  'te',
#  'j',
#  'j2',
#  'jz',
#  'vrxy',
#  'vcxy',
#  'vphi',
#  'vtheta',
#  'v_mean',
#  'v_disp',
#  'v_curl',
#  'vorticity',
#  'v_div',
#  'age',
#  'u_mag',
#  'u_lum_den',
#  'b_mag',
#  'b_lum_den',
#  'v_mag',
#  'v_lum_den',
#  'r_mag',
#  'r_lum_den',
#  'i_mag',
#  'i_lum_den',
#  'j_mag',
#  'j_lum_den',
#  'h_mag',
#  'h_lum_den',
#  'k_mag',
#  'k_lum_den',
#  'U_mag',
#  'U_lum_den',
#  'B_mag',
#  'B_lum_den',
#  'V_mag',
#  'V_lum_den',
#  'R_mag',
#  'R_lum_den',
#  'I_mag',
#  'I_lum_den',
#  'J_mag',
#  'J_lum_den',
#  'H_mag',
#  'H_lum_den',
#  'K_mag',
#  'K_lum_den',
#  'theta',
#  'alt',
#  'az',
#  'cs',
#  'mu',
#  'p',
#  'u',
#  'temp',
#  'zeldovich_offset',
#  'aform',
#  'tform',
#  'iord_argsort',
#  'smooth',
#  'rho',
#  'eps',
#  'phi',
#  'pos',
#  'mass',
#  'vel']

# %%
def makeGalQtyCSV(gal, startTS=0, export=True):
    baseDir = '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms'
    galDir = baseDir+ '/r' + str(gal)+'.romulus25.3072g1HsbBH'

    timesteps = glob.glob(galDir+'/r*.romulus25.3072g1HsbBH.0*')
    timesteps.sort(reverse=True)
    
    if export:
        # setup file for exporting values
        outfile = '/home/jw1624/H1-merian/csvs/breathingModes/r'+str(gal)+'_qtys.txt'
        if startTS == 0:
            fout = open(outfile,'w')
            fout.write('galaxyID,timestep,t,z,')
            fout.write('M_star,R_halflight,R_halfmass,')
            fout.write('sigma_gas,sigma_star,')
            fout.write('SFR_10,SFR_100,sSFR_10,sSFR_100\n')
            fout.close()
    
    # iterate through each timestep
    for timestep in timesteps[startTS:]:
        print(timestep)
        if export: fout = open(outfile, 'a')
        tstepnumber = timestep[-6:]

        # I'm assuming that if there's another subfolder, the sim is inside it

        # try to find sim file in current folder
        simFile = timestep+'/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
        # check if there's another folder
        a=glob.glob(timestep+'/*')
        if len(a)>0:
            # find sim in folder
            simFile = timestep+'/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
            #simFile+= '/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
            print(glob.glob(simFile)) 
            
        #print(glob.glob(simFile))
        # handle sim file not existing
        if len(glob.glob(simFile)) == 0:
            print('FNF for halo ' + str(gal) + ', timestep '+tstepnumber)
            continue

        # open simfile 
        sCDM = pynbody.load(simFile)

        sCDM.physical_units()
        
        # SFR and sSFR (do first otherwise we sometimes get an error)
        SFR_10  = sum(sCDM.s['mass'][sCDM.s['age'].in_units('Myr')<10])
        SFR_100 = sum(sCDM.s['mass'][sCDM.s['age'].in_units('Myr')<100])
        
        hCDM = -1
        try:
            hCDM = sCDM.halos(write_fpos=False)[1]
        except:
            # center manually if missing halo; taken from pynbody source code
            #print('HNF for halo ' + str(gal) + ', timestep '+str(tstepnumber))
            i = sCDM['phi'].argmin()
            cen_pot = sCDM['pos'][i].copy()
            sCDM['pos'] -= cen_pot
        else:
            hCDM = sCDM.halos(write_fpos=False)[1]
            cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
            sCDM['pos'] -= cen_pot
            
            pynbody.analysis.angmom.faceon(hCDM)

        # get age of universe
        uage = pynbody.analysis.cosmology.age(sCDM)
        # get redshift
        stepZ = pynbody.analysis.cosmology.redshift(sCDM, uage)

        # Mass
        mStar = sum(sCDM.s['mass'])

        # Sizes
        #rVir = pynbody.analysis.halo.virial_radius(sCDM)
        rHL = pynbody.analysis.luminosity.half_light_r(sCDM)

        rHM = halfMassRadius(sCDM, 0, 1, 0.1)
        rHM = halfMassRadius(sCDM,rHM*0.85, 0.05, 0.01)

        # velocity dispersion
        sCDM.properties['boxsize'] = 3.0e4
        sigma_gas = np.median(sCDM.g['v_disp'])
        sigma_star= np.median(sCDM.s['v_disp'])

        # sSFR
        sSFR_10 = SFR_10/mStar
        sSFR_100 = SFR_100/mStar

        if export:
            # write to file
            fout.write(str(gal)+','+str(tstepnumber)+','+str(uage)+','+str(stepZ)+',')
            #fout.write(str(mStar)+','+str(rVir)+','+str(rHL)+','+str(rHM)+',')
            fout.write(str(mStar)+','+str(rHL)+','+str(rHM)+',')
            fout.write(str(sigma_gas)+','+str(sigma_star)+',')
            fout.write(str(SFR_10)+','+str(SFR_100)+','+str(sSFR_10)+','+str(sSFR_100)+'\n')

            fout.close()
        print('r'+str(gal)+' '+str(tstepnumber)+' done')

# %%
makeGalQtyCSV(568, export=False)
# Out:
# /data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r568.romulus25.3072g1HsbBH/r568.romulus25.3072g1HsbBH.004096
# ['/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r568.romulus25.3072g1HsbBH/r568.romulus25.3072g1HsbBH.004096/r568.romulus25.3072g1HsbBH.004096']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 makeGalQtyCSV(568, export=False)
#
# Cell In[27], line 80, in makeGalQtyCSV(gal, startTS, export)
#      76 # Sizes
#      77 #rVir = pynbody.analysis.halo.virial_radius(sCDM)
#      78 rHL = pynbody.analysis.luminosity.half_light_r(sCDM)
# ---> 80 rHM = halfMassRadius(sCDM, 0, 1, 0.1)
#      81 rHM = halfMassRadius(sCDM,rHM*0.85, 0.05, 0.01)
#      83 # velocity dispersion
#
# NameError: name 'halfMassRadius' is not defined

# %%
for gal in currentGals[1:]:
    makeGalQtyCSV(gal)
# Out:
# r468 000069 done
# r468 000096 done
# r468 000105 done
# r468 000136 done
# r468 000186 done
# r468 000192 done
# r468 000223 done
# r468 000273 done
# r468 000288 done
# r468 000345 done
# r468 000384 done
# r468 000454 done
# r468 000480 done
# r468 000576 done
# r468 000635 done
# r468 000672 done
# r468 000768 done
# r468 000775 done
# r468 000864 done
# r468 000960 done
# r468 000972 done
# r468 001056 done
# r468 001104 done
# r468 001152 done
# r468 001248 done
# r468 001268 done
# r468 001344 done
# r468 001440 done
# r468 001474 done
# r468 001536 done
# r468 001632 done
# r468 001728 done
# r468 001739 done
# r468 001824 done
# r468 001920 done

# %% [markdown]
# ## Single Timestep Investigating

# %%
gal = currentGals[0]

baseDir = '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms'
galDir = baseDir+ '/r' + str(gal)+'.romulus25.3072g1HsbBH'

timesteps = glob.glob(galDir+'/r*.romulus25.3072g1HsbBH.0*')
timesteps.sort(reverse=True)
timesteps
# Out:
# ['/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.004096',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.004032',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003936',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003840',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003744',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003648',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003606',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003552',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003456',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003360',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003264',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003195',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003168',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.003072',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002976',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002880',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002784',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002688',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002592',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002554',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002496',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002400',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002304',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002208',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002112',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002087',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.002016',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001920',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001824',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001739',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001728',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001632',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001536',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001474',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001440',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001344',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001268',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001248',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001152',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001104',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.001056',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000972',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000960',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000864',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000775',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000768',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000672',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000635',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000576',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000480',
#  '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms/r431.romulus25.3072g1HsbBH/r431.romulus25.3072g1HsbBH.000454']

# %%
timestep = timesteps[-13]
tstepnumber = timestep[-6:]

# try to find sim file in current folder
simFile = timestep+'/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
# check if there's another folder
a=glob.glob(timestep+'/*/*')
if len(a)>0:
    # find sim in folder
    simFile = timestep+'/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
    simFile+= '/r'+str(gal)+'.romulus25.3072g1HsbBH.'+tstepnumber
    #print(glob.glob(simFile)) 

#print(glob.glob(simFile))
# handle sim file not existing
if len(glob.glob(simFile)) == 0:
    print('FNF for halo ' + str(gal) + ', timestep '+tstepnumber)

# open simfile 
sCDM = pynbody.load(simFile)

sCDM.physical_units()

# SFR and sSFR (do first otherwise we sometimes get an error)
SFR_10  = sum(sCDM.s['mass'][sCDM.s['age'].in_units('Myr')<10])
SFR_100 = sum(sCDM.s['mass'][sCDM.s['age'].in_units('Myr')<100])

hCDM = -1
# Out:
# /home/jw1624/miniconda3/lib/python3.9/site-packages/pynbody/snapshot/tipsy.py:124: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   warnings.warn(

# %%
hCDM = -1
try:
    hCDM = sCDM.halos(write_fpos=False)[1]
except:
    # center manually if missing halo; taken from pynbody source code
    #print('HNF for halo ' + str(gal) + ', timestep '+str(tstepnumber))
    print('doing manual centering')
    i = sCDM['phi'].argmin()
    cen_pot = sCDM['pos'][i].copy()
    sCDM['pos'] -= cen_pot
else:
    hCDM = sCDM.halos(write_fpos=False)[1]
    cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
    sCDM['pos'] -= cen_pot

    pynbody.analysis.angmom.faceon(hCDM)
# Out:
# doing manual centering

# %%
# get age of universe
uage = pynbody.analysis.cosmology.age(sCDM)
# get redshift
stepZ = pynbody.analysis.cosmology.redshift(sCDM, uage)

# Mass
mStar = sum(sCDM.s['mass'])

# Sizes
#rVir = pynbody.analysis.halo.virial_radius(sCDM)
rHL = pynbody.analysis.luminosity.half_light_r(sCDM)
# Out:
# /home/jw1624/miniconda3/lib/python3.9/site-packages/pynbody/simdict.py:92: RuntimeWarning: Assuming default value for property 'a'=1.00e+00
#   warnings.warn("Assuming default value for property '{}'={:.2e}".format(
# /home/jw1624/miniconda3/lib/python3.9/site-packages/pynbody/simdict.py:92: RuntimeWarning: Assuming default value for property 'h'=6.78e-01
#   warnings.warn("Assuming default value for property '{}'={:.2e}".format(
# /home/jw1624/miniconda3/lib/python3.9/site-packages/pynbody/simdict.py:92: RuntimeWarning: Assuming default value for property 'omegaM0'=3.09e-01
#   warnings.warn("Assuming default value for property '{}'={:.2e}".format(
# /home/jw1624/miniconda3/lib/python3.9/site-packages/pynbody/simdict.py:92: RuntimeWarning: Assuming default value for property 'omegaL0'=6.91e-01
#   warnings.warn("Assuming default value for property '{}'={:.2e}".format(

# %%
rHL
# Out:
# SimArray(0.34249912, 'kpc')

# %%
tstepnumber
# Out:
# '001152'

# %%
uage
# Out:
# 13.795660358777317

# %% [markdown]
# ## Morphology

# %%
currentGals
# Out:
# array([431, 442, 468, 492, 502, 515, 523, 556, 568, 569, 571, 597, 613,
#        615, 618, 634])

# %%
gal = currentGals[0]
tsidx = 0
R = 6

baseDir = '/data/REPOSITORY/e11Gals/romulus_dwarf_zooms'
galDir = baseDir+ '/r' + str(gal)+'.romulus25.3072g1HsbBH'

timesteps = glob.glob(galDir+'/r*.romulus25.3072g1HsbBH.0*')
timesteps.sort(reverse=True)

tsnum = timesteps[tsidx][-4:]
tsfile = glob.glob(timesteps[tsidx]+'/r*.00'+tsnum)[0]

sCDM = pynbody.load(tsfile)
sCDM.physical_units()

hCDM = sCDM.halos(write_fpos=False)[1]
cen_pot = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
sCDM['pos'] -= cen_pot

rbin, ba, ca, angle, es = pynbody.analysis.halo.halo_shape(sCDM, rout=1.1*R, N=1, rin = 1*R)

# %%
rbin[-1]
# Out:
# 6.29766649502923

# %%
ba[-1]
# Out:
# 0.966829532681573

# %%
ca[-1]
# Out:
# 0.5544317600532499

# %%
radii = np.linalg.norm(sCDM['pos'], axis=1)
plt.hist(radii, density=True)
# Out:
# (array([2.71407619e-04, 2.14286856e-05, 7.66519145e-06, 3.89188949e-05,
#         2.12487322e-05, 1.23132540e-05, 6.22960451e-06, 4.41423260e-06,
#         5.05536305e-07, 1.39871705e-08]),
#  array([    0.        ,  2603.17869713,  5206.35739426,  7809.53609139,
#         10412.71478851, 13015.89348564, 15619.07218277, 18222.2508799 ,
#         20825.42957703, 23428.60827416, 26031.78697129]),
#  <BarContainer object of 10 artists>)

# %%
sCDM['pos']
# Out:
# SimArray([[-2.77027935e+03, -2.57217325e+01, -8.97652283e+02],
#           [-1.74130201e+03,  2.56881490e+02,  4.89775091e+01],
#           [-1.46816969e+03, -1.15299784e+02, -2.15330720e+02],
#           ...,
#           [ 5.36199659e+00,  6.28018752e+00,  1.02818012e-01],
#           [ 3.50195915e+00,  1.87512487e+00,  8.31671059e+00],
#           [ 4.03784215e+00,  9.03941691e-01,  8.87066126e+00]], 'kpc')

# %% [markdown]
# # Bridge

# %%
def halfMassRadius_bisect(positions, masses, outerR, acc, maxiter=100000):
    innerLim = 0.0
    outerLim = outerR

    pRadii = np.linalg.norm(positions, ord=2, axis=1)
    mTot = sum(masses)

    r = outerR/2
    hm = sum(masses[pRadii < r])
    n=0
    while(hm < (0.50-acc)*mTot or hm > (0.5+acc)*mTot):
        if hm > 0.5*mTot: # too big, decrease r
            outerLim = r
            r = innerLim + (outerLim-innerLim)/2
        elif hm < 0.5*mTot: # too small, increase r
            innerLim = r
            r = innerLim + (outerLim-innerLim)/2
        hm = sum(masses[pRadii < r])

        n += 1
        if n>maxiter:
            return -1
            break

    return r

# %%
gal = 468
ts0 = 0
ts1 = 1

# load ts0
simfile0 = util_os.getfilepath_cdm(468,ts0)

sZero = pynbody.load(simfile0)
sZero.physical_units()

# load ts1
simfile1 = util_os.getfilepath_cdm(468,ts1)
    
sOne = pynbody.load(simfile1)
sOne.physical_units()

# %%
hZero = sZero.halos()[1]
haloCen = pynbody.analysis.halo.center(hZero, mode='pot', retcen=True)

Rhm0 = halfMassRadius_bisect(hZero.s['pos']-haloCen, hZero.s['mass'], 1000, 0.01)

# %%
# testing how well we capture the galaxy in snapshot 0
fig, ax = plt.subplots(1,1)

rfac = 50
dfac = 5.0
galmask = np.linalg.norm(sZero.s['pos'].in_units('kpc') - haloCen, axis=1)<rfac*Rhm0
dmmask = np.linalg.norm(sZero.d['pos'].in_units('kpc') - haloCen, axis=1)<dfac*rfac*Rhm0

plt.scatter(sZero.s['pos'][:,0][galmask], sZero.s['pos'][:,1][galmask], s=1)
plt.scatter(sZero.d['pos'][:,0][dmmask], sZero.d['pos'][:,1][dmmask], s=1, alpha = 0.01)

c1 = plt.Circle((haloCen[0],haloCen[1]), rfac*Rhm0, edgecolor='g', linewidth=3, fill=False)
c2 = plt.Circle((haloCen[0],haloCen[1]), dfac*rfac*Rhm0, edgecolor='c', linewidth=3, fill=False)

ax.add_patch(c1)
ax.add_patch(c2)

# %%
# testing how well this translates to the next snapshot
fig, axs = plt.subplots(1,3, figsize=(18,6))

mtot = sOne.s['mass'].sum()
oneCen = np.sum(sOne.s['mass'] * sOne.s['pos'].transpose(),
             axis=1) / mtot
oneCen.units = sOne.s['pos'].units

# x-y plane
axs[0].scatter(sOne.s['pos'][:,0], sOne.s['pos'][:,1], s=1)
axs[0].scatter(sOne.d['pos'][:,0], sOne.d['pos'][:,1], s=1, alpha = 0.01)

c01 = plt.Circle((oneCen[0],oneCen[1]), rfac*Rhm0, edgecolor='g', linewidth=1, fill=False)
c02 = plt.Circle((oneCen[0],oneCen[1]), dfac*rfac*Rhm0, edgecolor='cyan', linewidth=1, fill=False)
axs[0].add_patch(c01)
axs[0].add_patch(c02)

hw = 600
axs[0].set_xlim([oneCen[0]-hw,oneCen[0]+hw])
axs[0].set_ylim([oneCen[1]-hw,oneCen[1]+hw])

fs = 16
axs[0].set_xlabel('x', fontsize=fs)
axs[0].set_ylabel('y', fontsize=fs)

#axs[0].legend(handles=[c01,c02], labels=['Star Mask','DM Mask'], loc='upper right')

# x-z plane
axs[1].scatter(sOne.s['pos'][:,0], sOne.s['pos'][:,2], s=1)
axs[1].scatter(sOne.d['pos'][:,0], sOne.d['pos'][:,2], s=1, alpha = 0.01)

c11 = plt.Circle((oneCen[0],oneCen[2]), rfac*Rhm0, edgecolor='g', linewidth=1, fill=False)
c12 = plt.Circle((oneCen[0],oneCen[2]), dfac*rfac*Rhm0, edgecolor='cyan', linewidth=1, fill=False)
axs[1].add_patch(c11)
axs[1].add_patch(c12)

axs[1].set_xlim([oneCen[0]-hw,oneCen[0]+hw])
axs[1].set_ylim([oneCen[2]-hw,oneCen[2]+hw])

axs[1].set_xlabel('x', fontsize=fs)
axs[1].set_ylabel('z', fontsize=fs)

# y-z plane 
axs[2].scatter(sOne.s['pos'][:,1], sOne.s['pos'][:,2], s=1)
axs[2].scatter(sOne.d['pos'][:,1], sOne.d['pos'][:,2], s=1, alpha = 0.01)

c21 = plt.Circle((oneCen[1],oneCen[2]), rfac*Rhm0, edgecolor='g', linewidth=1, fill=False)
c22 = plt.Circle((oneCen[1],oneCen[2]), dfac*rfac*Rhm0, edgecolor='cyan', linewidth=1, fill=False)
axs[2].add_patch(c21)
axs[2].add_patch(c22)

axs[2].set_xlim([oneCen[1]-hw,oneCen[1]+hw])
axs[2].set_ylim([oneCen[2]-hw,oneCen[2]+hw])

axs[2].set_xlabel('y', fontsize=fs)
axs[2].set_ylabel('z', fontsize=fs)

plt.suptitle('r'+str(gal), weight='bold', fontsize=20)

plt.tight_layout()

# %%
starmask = np.linalg.norm(sOne.s['pos']-oneCen, axis=1)<rfac*Rhm0
np.log10(sum(sOne.s['mass'][starmask]))
# Out:
# 9.311975098472901

# %% [markdown]
# ## Tracking DM particles by index

# %%
gal = 442
fCDM = util_os.getfilepath_cdm(gal, 0)

sCDM = pynbody.load(fCDM)
sCDM.physical_units()
hCDM = sCDM.halos()[1]

xmask = np.nonzero(np.in1d(sCDM.d['pos'][:,0], hCDM.d['pos'][:,0]))
ymask = np.nonzero(np.in1d(sCDM.d['pos'][:,1], hCDM.d['pos'][:,1]))
zmask = np.nonzero(np.in1d(sCDM.d['pos'][:,2], hCDM.d['pos'][:,2]))

fullmask = np.intersect1d(xmask, ymask)
fullmask = np.intersect1d(fullmask, zmask)

# %%
# plot all DM and halo dm 
# testing how well this translates to the next snapshot
fig, axs = plt.subplots(1,3, figsize=(18,6))

mtot = hCDM.d['mass'].sum()
cen = np.sum(hCDM.d['mass'] * hCDM.d['pos'].transpose(),
             axis=1) / mtot
cen.units = hCDM.d['pos'].units

rad = util_galaxies.compute_massRadius(hCDM.d['pos'], hCDM.d['mass'], 1000, 0.1, frac=0.50, maxiter=1000)

rfac = 3

hw = 300
fs = 16

xdims = [0,0,1]
ydims = [1,2,2]
dims = ['x', 'y', 'z']
for i,ax in enumerate(axs):
    # all gas 
    ax.scatter(sCDM.g['pos'][:,xdims[i]], sCDM.g['pos'][:,ydims[i]], s=1, c='blue', alpha=0.01)
    
    # all DM
    ax.scatter(sCDM.d['pos'][:,xdims[i]], sCDM.d['pos'][:,ydims[i]], s=1, alpha = 0.01, c='grey')
    # halo DM
    ax.scatter(sCDM.d['pos'][:,xdims[i]][fullmask], sCDM.d['pos'][:,ydims[i]][fullmask], s=1, c='k')
    
    # all stars 
    ax.scatter(sCDM.s['pos'][:,xdims[i]], sCDM.s['pos'][:,ydims[i]], s=1, c='tab:orange')
    # halo stars 
    ax.scatter(hCDM.s['pos'][:,xdims[i]], hCDM.s['pos'][:,ydims[i]], s=1, c='tab:green')
    
    c1 = plt.Circle((cen[xdims[i]], cen[ydims[i]]), 3*rad, edgecolor='cyan', linewidth=1, fill=False)
    ax.add_patch(c1)
    
    ax.set_xlim([cen[xdims[i]]-hw,cen[xdims[i]]+hw])
    ax.set_ylim([cen[ydims[i]]-hw,cen[ydims[i]]+hw])

    ax.set_xlabel(dims[xdims[i]], fontsize=fs)
    ax.set_ylabel(dims[ydims[i]], fontsize=fs)

plt.suptitle('r'+str(gal), weight='bold', fontsize=20)

#axs[0].legend(['Non-Halo DM', 'Halo DM', 'Non-Halo Stars', 'Halo Stars'])

plt.tight_layout()

# %%
sCDM.g.all_keys()
# Out:
# ['HII',
#  'HeIII',
#  'ne',
#  'hetot',
#  'hydrogen',
#  'feh',
#  'oxh',
#  'ofe',
#  'mgfe',
#  'nefe',
#  'sife',
#  'c_s',
#  'c_s_turb',
#  'mjeans',
#  'mjeans_turb',
#  'ljeans',
#  'ljeans_turb',
#  'r',
#  'rxy',
#  'vr',
#  'v2',
#  'vt',
#  'ke',
#  'te',
#  'j',
#  'j2',
#  'jz',
#  'vrxy',
#  'vcxy',
#  'vphi',
#  'vtheta',
#  'v_mean',
#  'v_disp',
#  'v_curl',
#  'vorticity',
#  'v_div',
#  'age',
#  'u_mag',
#  'u_lum_den',
#  'b_mag',
#  'b_lum_den',
#  'v_mag',
#  'v_lum_den',
#  'r_mag',
#  'r_lum_den',
#  'i_mag',
#  'i_lum_den',
#  'j_mag',
#  'j_lum_den',
#  'h_mag',
#  'h_lum_den',
#  'k_mag',
#  'k_lum_den',
#  'U_mag',
#  'U_lum_den',
#  'B_mag',
#  'B_lum_den',
#  'V_mag',
#  'V_lum_den',
#  'R_mag',
#  'R_lum_den',
#  'I_mag',
#  'I_lum_den',
#  'J_mag',
#  'J_lum_den',
#  'H_mag',
#  'H_lum_den',
#  'K_mag',
#  'K_lum_den',
#  'theta',
#  'alt',
#  'az',
#  'cs',
#  'mu',
#  'p',
#  'u',
#  'temp',
#  'zeldovich_offset',
#  'aform',
#  'tform',
#  'iord_argsort',
#  'smooth',
#  'rho',
#  'metals',
#  'mass',
#  'rho',
#  'pos',
#  'phi',
#  'vel',
#  'amiga.grp',
#  'eps',
#  'temp']

# %%
# testing below fit with our dm mask
sCDM['pos']-=cen

hCDM = sCDM.d[fullmask]

pynbody.analysis.angmom.faceon(hCDM)
pDM = pynbody.analysis.profile.Profile(hCDM.d, rmin='0.01 kpc', rmax='50 kpc', type='lin', nbins=200)

# %%
plt.plot(pDM['rbins'], pDM['density'])

fitR = np.array(pDM['rbins'][:6])
fitD = np.array(pDM['density'][:6])
plt.plot(fitR, fitD)

alpha, c = opt.curve_fit(powerlaw, fitR, fitD, maxfev=1000, p0=[-1,max(fitD)])[0]
plt.plot(fitR, powerlaw(fitR, alpha, c))

plt.xscale('log')
plt.yscale('log')
alpha
# Out:
# -0.1423720913087843

# %% [markdown]
# ## Fitting Alpha

# %%
# power law
def powerlaw(r, alpha, c):
    return c*(r**alpha)

# %%
fCDM = util_os.getfilepath_cdm(431, 0)

sCDM = pynbody.load(fCDM)
sCDM.physical_units()

hCDM = sCDM.halos()[1]

# %%
# prolly need to center for profile
cen = pynbody.analysis.halo.center(hCDM, mode='pot', retcen=True)
sCDM['pos'] -= cen

pynbody.analysis.angmom.faceon(hCDM)

pDM = pynbody.analysis.profile.Profile(hCDM.d, rmin='0.01 kpc', rmax='50 kpc', type='lin', nbins=200)

# %%
plt.plot(pDM['rbins'], pDM['density'])

fitR = np.array(pDM['rbins'][:6])
fitD = np.array(pDM['density'][:6])
plt.plot(fitR, fitD)

alpha, c = opt.curve_fit(powerlaw, fitR, fitD, maxfev=1000, p0=[1,max(fitD)])[0]
plt.plot(fitR, powerlaw(fitR, alpha, c))

plt.xscale('log')
plt.yscale('log')

# %%
alpha
# Out:
# -0.13998328097486407

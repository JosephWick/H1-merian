# %%
import gizmo_analysis as gizmo
import utilities as ut

import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

import scipy.optimize as opt

import glob

import sys
sys.path.insert(0, '../util/')
from util_os import util_os
from util_galaxies import util_galaxies

# %%
dpath = '/data/groups/leauthaud/yluo42/FIRE/'

# %%
simfiles = glob.glob(dpath+'/m*')

# %%
simfiles
# Out:
# ['/data/groups/leauthaud/yluo42/FIRE/m11b_r2100',
#  '/data/groups/leauthaud/yluo42/FIRE/m11e_r7100',
#  '/data/groups/leauthaud/yluo42/FIRE/m11h_r7100',
#  '/data/groups/leauthaud/yluo42/FIRE/m11q_r880',
#  '/data/groups/leauthaud/yluo42/FIRE/m11d_r7100',
#  '/data/groups/leauthaud/yluo42/FIRE/m11i_r7100']

# %%
gal = simfiles[2]
particles = gizmo.io.Read.read_snapshots('all', 'redshift', 0, gal)
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11h_r7100/snapshot_times.txt
#
# * input redshift = 0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11h_r7100/output/snapshot_600.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 15799600 particles
#     dark2     (id = 2): 4341648 particles
#     gas       (id = 0): 15054933 particles
#     star      (id = 4): 744667 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11h_r7100/output/snapshot_600.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11h_r7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
# ! warning: gas mass [min, med, max] = [7126.535, 7126.535, 37329.543]
# ! warning: star mass [min, med, max] = [3662.156, 5332.682, 25063.770]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11h_r7100/track/host_coordinates.hdf5
#   host1 position = (39874.23, 42037.49, 46218.98) [kpc comoving]
#   host1 velocity = (-90.7, -23.0, 103.2) [km / s]
#   host1 axis ratios = (0.22, 0.27, 0.81)

# %%
particles.keys()
# Out:
# dict_keys(['dark', 'dark2', 'gas', 'star'])

# %%
particles['gas'].keys()
# Out:
# dict_keys(['position', 'density', 'electron.fraction', 'temperature', 'mass', 'massfraction', 'hydrogen.neutral.fraction', 'id.child', 'id.generation', 'id', 'size', 'sfr', 'velocity'])

# %%
mass_allstars = particles['star'].prop('mass')
age_allstars = particles['star'].prop('age')
pos_allstars = particles['star'].prop('position')
vel_allstars = particles['star'].prop('host.velocity')

# %%
mass_allstars.shape
# Out:
# (326376,)

# %%
pos_allstars.shape
# Out:
# (326376, 3)

# %%
# DM center of mass
pos_DM = particles['dark'].prop('position')
mass_DM= particles['dark'].prop('mass')
com = np.sum(pos_DM * mass_DM[:, None], axis=0) / np.sum(mass_DM)

# %%
plt.scatter(pos_DM[:,0], pos_DM[:,1], s=1)
plt.scatter(pos_allstars[:,0], pos_allstars[:,1], s=1)

# %%
# make a cut for all particles within 2000 kpc of dark matter CoM
posmask = np.linalg.norm(pos_allstars-com, axis=1)<2000
mass_allstars = mass_allstars[posmask]
age_allstars = age_allstars[posmask]
pos_allstars = pos_allstars[posmask]
vel_allstars = vel_allstars[posmask]

# %%
pos_allstars.shape
# Out:
# (320264, 3)

# %%
com_star = np.sum(pos_allstars * mass_allstars[:, None], axis=0) / np.sum(mass_allstars)

posmask = np.linalg.norm(pos_allstars-com_star) < 100
mass_allstars = mass_allstars[posmask]
age_allstars = age_allstars[posmask]
pos_allstars = pos_allstars[posmask]
vel_allstars = vel_allstars[posmask]

# %% [markdown]
# # Spatial distro of particles

# %%
def compute_Rhalfmass_bisect(positions, masses, outerR, acc, maxiter=100000):
    innerLim = 0.0
    outerLim = outerR

    pRadii = np.linalg.norm(positions, ord=2, axis=1)
    mTot = sum(masses)

    r = outerR/2
    hm = sum(masses[pRadii < r])
    n=0
    while(hm < (0.50-acc)*mTot or hm > (0.5+acc)*mTot):
        if hm > 0.5*mTot: # too big, decrease r
            outerLim = r
            r = innerLim + (outerLim-innerLim)/2
        elif hm < 0.5*mTot: # too small, increase r
            innerLim = r
            r = innerLim + (outerLim-innerLim)/2
        hm = sum(masses[pRadii < r])

        n += 1
        if n>maxiter:
            return -1
            break

    return r

# %%
mass_allstars.shape
# Out:
# (194639,)

# %%
pos_allstars.shape
# Out:
# (194639, 3)

# %%
mass_allstars = particles['star'].prop('mass')
age_allstars = particles['star'].prop('age')
pos_allstars = particles['star'].prop('position')
vel_allstars = particles['star'].prop('host.velocity')

pos_alldm = particles['dark'].prop('position')
mass_alldm= particles['dark'].prop('mass')

# DM center of mass
com = np.sum(pos_alldm * mass_alldm[:, None], axis=0) / np.sum(mass_alldm)

pos_allstars -= com
pos_alldm -= com 

# cut by within 2000 kpc of com 
starmask = np.linalg.norm(pos_allstars, axis=1)<500
pos_allstars = pos_allstars[starmask]
mass_allstars = mass_allstars[starmask]

dmmask = np.linalg.norm(pos_alldm, axis=1)<2000
pos_alldm = pos_alldm[dmmask]
mass_alldm = mass_alldm[dmmask]

# %%
# star center of mass
com_star = np.sum(pos_allstars * mass_allstars[:, None], axis=0) / np.sum(mass_allstars)

hmr = compute_Rhalfmass_bisect(pos_allstars-com_star, mass_allstars, 1000, 0.01)

# %%
fig, ax = plt.subplots(1,1)

plt.scatter(pos_alldm[:,0], pos_alldm[:,1], s=1, c='grey', alpha=0.01)
plt.scatter(pos_allstars[:,0], pos_allstars[:,1], s=1)

c1 = matplotlib.patches.Circle(radius=hmr, xy=(com_star[0],com_star[1]), ec='r', fill=False)

ax.add_patch(c1)

ax.set_xlim([-200,200])
ax.set_ylim([-200,200])
# Out:
# (-200.0, 200.0)

# %%
len(pos_alldm)
# Out:
# 10318605

# %%
hmr
# Out:
# 3.90625

# %%
np.linspace(1,10,20)
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
len(bmask)
# Out:
# 4568709

# %%
len(mass_seldm)
# Out:
# 5173

# %% [markdown]
# ## parsing redshifts for snapshot

# %%
gal
# Out:
# '/data/groups/leauthaud/yluo42/FIRE/m11e_r7100'

# %%
zfile = '/data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt'
simtimes = pd.read_csv(zfile, sep='\s+', skiprows=6, header=None)

st_tskey = 0
st_zkey = 2
st_tkey = 3
st_lbkey = 4

redshifts = np.flip(simtimes[st_zkey].to_numpy())

# %%
redshifts
# Out:
# array([0.00000000e+00, 1.59264000e-04, 3.18646000e-04, 4.77910000e-04,
#        6.37293000e-04, 7.96795000e-04, 9.56297000e-04, 1.11579900e-03,
#        1.27553900e-03, 1.43516100e-03, 1.59490100e-03, 3.19480900e-03,
#        4.79996200e-03, 6.41024100e-03, 8.02576500e-03, 9.64629700e-03,
#        1.12720730e-02, 1.29032140e-02, 1.45395990e-02, 1.61812310e-02,
#        1.78282260e-02, 1.94805860e-02, 2.11381910e-02, 2.28012800e-02,
hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23349.38, 20507.20, 22598.64) [kpc comoving]
#   host1 velocity = (-227.0, -334.4, -228.1) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.000318646:  using snapshot index = 598, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_598.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336883 particles
#     star      (id = 4): 37213 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_598.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 for z in redshifts:
# ----> 2     parts = gizmo.io.Read.read_snapshots('all', 'redshift', z, gal)
#
# File ~/gizmo_analysis/gizmo_analysis/gizmo_io.py:1046, in ReadClass.read_snapshots(self, species, snapshot_value_kind, snapshot_values, simulation_directory, snapshot_directory, track_directory, simulation_name, properties, elements, particle_subsample_factor, separate_dark_lowres, sort_dark_by_id, convert_float32, host_number, assign_hosts, assign_hosts_rotation, assign_orbits, assign_formation_coordinates, assign_pointers, check_properties)
#    1041 header = self.read_header(
#    1042     simulation_directory, snapshot_directory, 'index', snapshot_index, simulation_name
#    1043 )
#    1045 # read particles from snapshot file[s]
# -> 1046 part = self._read_particles(
#    1047     simulation_directory,
#    1048     snapshot_directory,
#    1049     'index',
#    1050     snapshot_index,
#    1051     properties,
#    1052     elements,
#    1053     convert_float32,
#    1054     header,
#    1055 )
#    1057 # assign auxilliary information to particle dictionary class
#    1058 # store header dictionary
#    1059 part.info = header
#
# File ~/gizmo_analysis/gizmo_analysis/gizmo_io.py:1960, in ReadClass._read_particles(self, simulation_directory, snapshot_directory, snapshot_value_kind, snapshot_value, properties, elements, convert_float32, header)
#    1957                             else:
#    1958                                 prop_read_name = part_read[prop_read_name]
# -> 1960                             part[spec_name][prop_name][
#    1961                                 part_index_lo:part_index_hi, :
#    1962                             ] = prop_read_name
#    1964                 part_indices_lo[spec_i] = part_index_hi  # set indices for next file
#    1966 print()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/anaconda3/envs/breathingModes/lib/python3.11/site-packages/h5py/_hl/dataset.py:1063, in Dataset.__array__(self, dtype)
#    1060 if self.size == 0:
#    1061     return arr
# -> 1063 self.read_direct(arr)
#    1064 return arr
#
# File ~/anaconda3/envs/breathingModes/lib/python3.11/site-packages/h5py/_hl/dataset.py:1024, in Dataset.read_direct(self, dest, source_sel, dest_sel)
#    1021     dest_sel = sel.select(dest.shape, dest_sel)
#    1023 for mspace in dest_sel.broadcast(source_sel.array_shape):
# -> 1024     self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#
# KeyboardInterrupt:

# %% [markdown]
# # Tryna do sigma HII near young stars

# %%
particles['star'].keys()
# Out:
# dict_keys(['position', 'mass', 'massfraction', 'id.child', 'id.generation', 'id', 'form.scalefactor', 'velocity'])

# %%
particles['gas'].keys()
# Out:
# dict_keys(['position', 'density', 'electron.fraction', 'temperature', 'mass', 'massfraction', 'hydrogen.neutral.fraction', 'id.child', 'id.generation', 'id', 'size', 'sfr', 'velocity'])

# %%
particles['gas'].prop('hydrogen.neutral.fraction')
# Out:
# array([3.3281340e-06, 3.0736608e-06, 3.2904097e-06, ..., 3.4495388e-06,
#        3.1478251e-06, 3.1407039e-06], dtype=float32)

# %%
particles['star'].prop('age')
# Out:
# array([0.12654654, 5.64533721, 0.1701614 , ..., 2.1373839 , 5.75147108,
#        4.22376443])

# %%
particles = gizmo.io.Read.read_snapshots('all', 'redshift', 0, gal)

mass_allstars = particles['star'].prop('mass')
age_allstars = particles['star'].prop('age')
pos_allstars = particles['star'].prop('position')
vel_allstars = particles['star'].prop('host.velocity')

pos_allgas = particles['gas'].prop('position')
mass_allgas = particles['gas'].prop('mass')*particles['gas'].prop('hydrogen.neutral.fraction')
velocity_allgas = particles['gas'].prop('host.velocity')

pos_alldm = particles['dark'].prop('position')
mass_alldm= particles['dark'].prop('mass')

# DM center of mass
com = np.sum(pos_alldm * mass_alldm[:, None], axis=0) / np.sum(mass_alldm)

pos_allstars -= com
pos_alldm -= com 
pos_allgas -= com

# cut by within 500 kpc of com 
starmask = np.linalg.norm(pos_allstars, axis=1)<500
pos_allstars = pos_allstars[starmask]
mass_allstars = mass_allstars[starmask]
age_allstars = age_allstars[starmask]

dmmask = np.linalg.norm(pos_alldm, axis=1)<2000
pos_alldm = pos_alldm[dmmask]

# first need all gas particles within 100 pc (0.1 kpc) of a young star 
# let's center by stellar mass 
com_star = np.sum(pos_allstars * mass_allstars[:, None], axis=0) / np.sum(mass_allstars)

pos_allstars -= com_star
pos_allgas -= com_star

youngstarmask = age_allstars<0.1

pos_youngstars = pos_allstars[youngstarmask]
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11e_r7100/snapshot_times.txt
#
# * input redshift = 0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11e_r7100/output/snapshot_600.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 11213040 particles
#     dark2     (id = 2): 3946497 particles
#     gas       (id = 0): 10886907 particles
#     star      (id = 4): 326376 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11e_r7100/output/snapshot_600.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11e_r7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11e_r7100/track/host_coordinates.hdf5
#   host1 position = (44675.39, 39964.53, 40615.55) [kpc comoving]
#   host1 velocity = (80.9, -131.2, -86.3) [km / s]
#   host1 axis ratios = (0.28, 0.63, 0.45)

# %%
# %%time
indexes = []
for pos in pos_youngstars[:10]:
    mask = np.linalg.norm(pos_allgas-pos,axis=1)<0.1
    print(True in mask)
    
    for i in np.where(mask==True)[0]:
        indexes.append(i)
        
indexes = np.unique(indexes)
# Out:
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# CPU times: user 2.51 s, sys: 1.34 s, total: 3.85 s
# Wall time: 3.84 s

# %%
pos_selgas = np.array(pos_allgas)[indexes]
mass_selgas = mass_allgas[indexes]
velocity_selgas = velocity_allgas[indexes]

util_galaxies.compute_vdisp_los(velocity_allgas, particles['gas'].prop('mass'),
        pos_selgas, velocity_selgas, 5, mass_selgas)
# Out:
# 10.504089363520121

# %%
plt.scatter(particles['gas'].prop('position')[:,0], particles['gas'].prop('position')[:,1], s=1)
plt.scatter(particles['star'].prop('position')[:,0], particles['star'].prop('position')[:,1], s=1)

# %% [markdown]
# ## 3 panel figure
# Need:
#  * sigma
#  * SSFR
#  * half mass radius

# %%
# use this for sSFR
particles['star'].prop('age')
masses = particles['star'].prop('mass')

# %%
# can calculate half mass radius here
starpos = particles['star'].prop('position')

# %%
# velocities
velocities_rad = particles['star'].prop('host.velocity.principal.spherical')[:, 0]  # radial velocity

velocities_3d = particles['star'].prop('host.velocity')

# %%
# Yifei's code for mass weighted 3D velocity distribution
def compute_vdisp(velocities, masses):
    center_of_mass_velocity = np.sum(velocities * masses[:, None], axis=0) / np.sum(masses)
    velocity_differences = velocities - center_of_mass_velocity
    velocity_differences_squared = np.sum(velocity_differences**2, axis=1)
    mass_weighted_dispersion = np.sqrt(np.sum(velocity_differences_squared * masses) / np.sum(masses))
    return mass_weighted_dispersion

# %%
#  mass weighted radial velocity distribytion
def compute_vdisp_rad(velocities, masses):
    center_of_mass_velocity = np.sum(velocities * masses, axis=0) / np.sum(masses)
    velocity_differences = velocities - center_of_mass_velocity
    velocity_differences_squared = np.sum(velocity_differences**2, axis=0)
    mass_weighted_dispersion = np.sqrt(np.sum(velocity_differences_squared * masses) / np.sum(masses))
    #return center_of_mass_velocity
    return mass_weighted_dispersion

# %%
velocities_3d
# Out:
# array([[  41.284645 ,   14.041922 ,   32.112816 ],
#        [  -7.9162774,   -3.7507262,   10.986878 ],
#        [ -41.625034 ,  -50.93744  ,   29.438032 ],
#        ...,
#        [ -27.491978 ,  -35.202248 ,   26.35589  ],
#        [ -29.708197 ,  -38.479324 ,   30.914165 ],
#        [-113.45388  , -166.52464  ,  -33.670742 ]], dtype=float32)

# %%
velocities_3d[:,1]
# Out:
# array([  14.041922 ,   -3.7507262,  -50.93744  , ...,  -35.202248 ,
#         -38.479324 , -166.52464  ], dtype=float32)

# %%
# positions are 3D 
def compute_Rhalfmass(positions, masses, startR, incBy, acc):
    center_of_mass = np.sum(positions * masses[:, None], axis=0) / np.sum(masses)
    correctedpos = positions-center_of_mass
    
    radii = np.linalg.norm(correctedpos, ord=2, axis=1)
    mTot = np.sum(masses)
    
    # start at startR and increment 
    r = startR - incBy
    hm = mTot
    while(hm < (0.50-acc)*mTot or hm > (0.5+acc)*mTot):
        r+=incBy
        hm = np.sum(masses[radii < r])
        
        # check bounds 
        if (r>max(radii)):
            return -1
    
    return r

# %%
center_of_mass = np.sum(starpos * masses[:, None], axis=0) / np.sum(masses)
radii = np.linalg.norm(starpos-center_of_mass, ord=2, axis=1)

# %%
max(radii)
# Out:
# 3373.96459972014

# %%
compute_Rhalfmass(starpos, masses, startR=38, incBy=0.01, acc=0.01)
# Out:
# 39.18999999999976

# %%
compute_vdisp(velocities_3d, masses)
# Out:
# 51.041153

# %%
compute_vdisp_rad(velocities_rad, masses)
# Out:
# 6910.5435

# %%
center_of_mass_velocity=1

# %%
velocities_3d*masses[:,None]
# Out:
# array([[  55686.234 ,   18940.256 ,   43314.938 ],
#        [ -10330.108 ,   -4894.3975,   14336.996 ],
#        [ -60441.023 ,  -73962.96  ,   42745.066 ],
#        ...,
#        [ -41837.312 ,  -53570.81  ,   40108.414 ],
#        [ -45828.41  ,  -59358.914 ,   47688.76  ],
#        [-161054.22  , -236391.19  ,  -47797.53  ]], dtype=float32)

# %%
velocities_rad*masses
# Out:
# array([-3.3153930e+04,  1.8547777e+02,  5.5631895e+04, ...,
#         7.8504180e+04,  8.8510133e+04,  2.8962588e+05], dtype=float32)

# %% [markdown]
# # Gas Fraction

# %%
gal = simfiles[5]
particles = gizmo.io.Read.read_snapshots('all', 'redshift', 0, gal);
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11i_r7100/snapshot_times.txt
#
# * input redshift = 0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11i_r7100/output/snapshot_600.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 4592104 particles
#     dark2     (id = 2): 3248534 particles
#     gas       (id = 0): 4397417 particles
#     star      (id = 4): 194680 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11i_r7100/output/snapshot_600.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11i_r7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
# ! warning: gas mass [min, med, max] = [7126.535, 7126.535, 44368.609]
# ! warning: star mass [min, med, max] = [3802.071, 5253.020, 27560.615]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11i_r7100/track/host_coordinates.hdf5
#   host1 position = (48158.68, 38568.77, 42326.56) [kpc comoving]
#   host1 velocity = (147.9, -149.1, -24.2) [km / s]
#   host1 axis ratios = (0.46, 0.75, 0.61)

# %%
mass_allstars = particles['star'].prop('mass')
age_allstars = particles['star'].prop('age')
pos_allstars = particles['star'].prop('position')
vel_allstars = particles['star'].prop('host.velocity')

pos_allgas = particles['gas'].prop('position')
mass_allgas = particles['gas'].prop('mass')*particles['gas'].prop('hydrogen.neutral.fraction')
velocity_allgas = particles['gas'].prop('host.velocity')

pos_alldm = particles['dark'].prop('position')
mass_alldm= particles['dark'].prop('mass')

# DM center of mass
com = np.sum(pos_alldm * mass_alldm[:, None], axis=0) / np.sum(mass_alldm)

pos_allstars -= com
pos_alldm -= com 
pos_allgas -= com

# cut by within `dist` kpc of com 
dist = 1000
starmask = np.linalg.norm(pos_allstars, axis=1)<dist
pos_allstars = pos_allstars[starmask]
mass_allstars = mass_allstars[starmask]
age_allstars = age_allstars[starmask]

gasmask = np.linalg.norm(pos_allgas, axis=1)<dist
mass_allgas = mass_allgas[gasmask]

fgas = np.sum(mass_allgas)/(np.sum(mass_allgas)+np.sum(mass_allstars))
print(gal)
print(fgas)
# Out:
# /data/groups/leauthaud/yluo42/FIRE/m11i_r7100
# 0.5489856

# %% [markdown]
# # Profiles

# %%
def powerlaw(r, alpha, c):
    return c*(r**alpha)

# %%
gal = simfiles[0]

zees = np.arange(0,0.25,0.0025)
alphas = []
for z in zees:
    particles = gizmo.io.Read.read_snapshots('all', 'redshift', z, gal)
    
    mass_allstars = particles['star'].prop('mass')
    age_allstars = particles['star'].prop('age')
    pos_allstars = particles['star'].prop('position')
    vel_allstars = particles['star'].prop('host.velocity')

    pos_alldm = particles['dark'].prop('position')
    mass_alldm= particles['dark'].prop('mass')

    # DM center of mass
    com = np.sum(pos_alldm * mass_alldm[:, None], axis=0) / np.sum(mass_alldm)

    pos_allstars -= com
    pos_alldm -= com 

    # cut by within 2000 kpc of com 
    starmask = np.linalg.norm(pos_allstars, axis=1)<2000
    pos_allstars = pos_allstars[starmask]
    mass_allstars = mass_allstars[starmask]

    dmmask = np.linalg.norm(pos_alldm, axis=1)<2000
    pos_alldm = pos_alldm[dmmask]
    mass_alldm = mass_alldm[dmmask]

    # star center of mass
    com_star = np.sum(pos_allstars * mass_allstars[:, None], axis=0) / np.sum(mass_allstars)

    hmr = compute_Rhalfmass_bisect(pos_allstars-com_star, mass_allstars, 1000, 0.01)

    # first, center based on stars 
    pos_alldm -= com_star
    pos_allstars -= com_star
    
    ## PROFILE

    # take radii 
    radii_alldm = np.linalg.norm(pos_alldm, axis=1)
    # make cut for DM particles within 100 kpc of star cen 
    radsmask = radii_alldm<100 
    pos_seldm = pos_alldm[radsmask]
    mass_seldm = mass_alldm[radsmask]
    radii_seldm = radii_alldm[radsmask]

    # bin 
    rmin = 0.01
    rmax = 50
    nbins = 200
    binedges = np.linspace(rmin, rmax, nbins+1)

    binmasses = np.zeros(nbins)
    for i in range(nbins):
        blower = binedges[i]
        bupper = binedges[i+1]
        # cut by lower 
        bmask = radii_seldm>blower
        mass_bin = mass_seldm[bmask]
        rads_bin = radii_seldm[bmask]
        # cut by upper 
        bmask = rads_bin<bupper
        mass_bin = mass_bin[bmask]

        binmasses[i] = np.sum(mass_bin)

        # divide by volume of bin 
        vol = (4/3)*np.pi*(bupper**3 - blower**3)
        binmasses[i]/=vol
        
    alphas.append(opt.curve_fit(powerlaw, binedges[:10], binmasses[:10])[0][0])
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_600.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336883 particles
#     star      (id = 4): 37213 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_600.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23348.86, 20506.42, 22598.10) [kpc comoving]
#   host1 velocity = (-227.1, -334.4, -228.1) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0025:  using snapshot index = 589, redshift = 0.003
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_589.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336883 particles
#     star      (id = 4): 37213 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_589.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23359.19, 20521.62, 22608.54) [kpc comoving]
#   host1 velocity = (-226.5, -334.7, -227.5) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.005:  using snapshot index = 588, redshift = 0.005
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_588.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336901 particles
#     star      (id = 4): 37195 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_588.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23364.38, 20529.26, 22613.78) [kpc comoving]
#   host1 velocity = (-226.2, -335.0, -227.2) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0075:  using snapshot index = 586, redshift = 0.008
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_586.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336921 particles
#     star      (id = 4): 37178 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_586.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23374.79, 20544.63, 22624.23) [kpc comoving]
#   host1 velocity = (-225.7, -335.5, -226.5) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.01:  using snapshot index = 585, redshift = 0.010
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_585.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22336952 particles
#     star      (id = 4): 37147 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_585.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23379.97, 20552.31, 22629.43) [kpc comoving]
#   host1 velocity = (-225.4, -335.4, -226.3) [km / s]
#   host1 axis ratios = (0.31, 0.33, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0125:  using snapshot index = 583, redshift = 0.013
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_583.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337031 particles
#     star      (id = 4): 37069 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_583.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23390.25, 20567.81, 22639.79) [kpc comoving]
#   host1 velocity = (-225.5, -335.5, -226.3) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.015:  using snapshot index = 582, redshift = 0.015
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_582.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337100 particles
#     star      (id = 4): 37000 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_582.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23395.44, 20575.57, 22644.98) [kpc comoving]
#   host1 velocity = (-226.0, -335.5, -226.8) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0175:  using snapshot index = 580, redshift = 0.018
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_580.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337118 particles
#     star      (id = 4): 36982 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_580.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23405.96, 20591.21, 22655.54) [kpc comoving]
#   host1 velocity = (-226.7, -334.7, -228.3) [km / s]
#   host1 axis ratios = (0.32, 0.34, 0.93)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.02:  using snapshot index = 579, redshift = 0.019
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_579.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337128 particles
#     star      (id = 4): 36972 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_579.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23411.25, 20599.06, 22660.88) [kpc comoving]
#   host1 velocity = (-226.4, -334.0, -228.7) [km / s]
#   host1 axis ratios = (0.32, 0.34, 0.93)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0225:  using snapshot index = 577, redshift = 0.023
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_577.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337139 particles
#     star      (id = 4): 36962 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_577.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23421.91, 20614.72, 22671.61) [kpc comoving]
#   host1 velocity = (-224.9, -333.1, -228.8) [km / s]
#   host1 axis ratios = (0.30, 0.32, 0.93)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.025:  using snapshot index = 576, redshift = 0.024
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_576.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337158 particles
#     star      (id = 4): 36943 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_576.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23427.22, 20622.55, 22677.01) [kpc comoving]
#   host1 velocity = (-224.1, -332.9, -228.6) [km / s]
#   host1 axis ratios = (0.30, 0.32, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0275:  using snapshot index = 574, redshift = 0.028
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_574.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337170 particles
#     star      (id = 4): 36931 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_574.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23437.76, 20638.24, 22687.85) [kpc comoving]
#   host1 velocity = (-222.9, -332.8, -228.0) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.93)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.03:  using snapshot index = 573, redshift = 0.030
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_573.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337226 particles
#     star      (id = 4): 36875 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_573.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23443.03, 20646.12, 22693.30) [kpc comoving]
#   host1 velocity = (-222.7, -332.5, -227.6) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0325:  using snapshot index = 571, redshift = 0.033
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_571.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337259 particles
#     star      (id = 4): 36842 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_571.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23453.63, 20661.89, 22704.13) [kpc comoving]
#   host1 velocity = (-222.6, -332.3, -226.8) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.035:  using snapshot index = 570, redshift = 0.035
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_570.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337277 particles
#     star      (id = 4): 36824 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_570.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23458.96, 20669.84, 22709.57) [kpc comoving]
#   host1 velocity = (-222.3, -332.7, -226.4) [km / s]
#   host1 axis ratios = (0.32, 0.34, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0375:  using snapshot index = 568, redshift = 0.038
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_568.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337283 particles
#     star      (id = 4): 36818 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_568.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23469.56, 20685.77, 22720.40) [kpc comoving]
#   host1 velocity = (-222.3, -333.8, -226.3) [km / s]
#   host1 axis ratios = (0.30, 0.32, 0.95)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.04:  using snapshot index = 567, redshift = 0.040
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_567.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337286 particles
#     star      (id = 4): 36815 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_567.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23474.88, 20693.83, 22725.84) [kpc comoving]
#   host1 velocity = (-222.6, -334.4, -226.4) [km / s]
#   host1 axis ratios = (0.30, 0.32, 0.95)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0425:  using snapshot index = 565, redshift = 0.043
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_565.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337315 particles
#     star      (id = 4): 36786 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_565.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23485.60, 20710.04, 22736.74) [kpc comoving]
#   host1 velocity = (-223.8, -335.0, -226.9) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.93)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.045:  using snapshot index = 564, redshift = 0.045
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_564.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337334 particles
#     star      (id = 4): 36767 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_564.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23491.05, 20718.21, 22742.26) [kpc comoving]
#   host1 velocity = (-224.4, -334.9, -227.2) [km / s]
#   host1 axis ratios = (0.33, 0.36, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0475:  using snapshot index = 563, redshift = 0.047
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_563.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337358 particles
#     star      (id = 4): 36743 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_563.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23496.57, 20726.39, 22747.76) [kpc comoving]
#   host1 velocity = (-224.6, -334.6, -227.4) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.05:  using snapshot index = 561, redshift = 0.050
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_561.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337394 particles
#     star      (id = 4): 36707 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_561.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23507.60, 20742.79, 22758.85) [kpc comoving]
#   host1 velocity = (-223.9, -333.8, -227.8) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0525:  using snapshot index = 560, redshift = 0.052
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_560.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337394 particles
#     star      (id = 4): 36707 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_560.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23513.09, 20750.92, 22764.44) [kpc comoving]
#   host1 velocity = (-223.3, -333.5, -227.7) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.055:  using snapshot index = 558, redshift = 0.055
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_558.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337416 particles
#     star      (id = 4): 36685 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_558.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23524.10, 20767.33, 22775.72) [kpc comoving]
#   host1 velocity = (-222.4, -333.6, -227.2) [km / s]
#   host1 axis ratios = (0.30, 0.35, 0.86)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0575:  using snapshot index = 557, redshift = 0.057
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_557.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337421 particles
#     star      (id = 4): 36680 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_557.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23529.59, 20775.52, 22781.37) [kpc comoving]
#   host1 velocity = (-222.3, -333.8, -226.5) [km / s]
#   host1 axis ratios = (0.30, 0.35, 0.85)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.06:  using snapshot index = 555, redshift = 0.061
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_555.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337450 particles
#     star      (id = 4): 36654 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_555.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23540.61, 20792.11, 22792.63) [kpc comoving]
#   host1 velocity = (-222.8, -334.2, -225.6) [km / s]
#   host1 axis ratios = (0.31, 0.36, 0.86)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0625:  using snapshot index = 554, redshift = 0.063
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_554.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337450 particles
#     star      (id = 4): 36654 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_554.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23546.18, 20800.47, 22798.24) [kpc comoving]
#   host1 velocity = (-222.9, -334.4, -225.7) [km / s]
#   host1 axis ratios = (0.32, 0.36, 0.88)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.065:  using snapshot index = 553, redshift = 0.064
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_553.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337481 particles
#     star      (id = 4): 36624 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_553.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23551.77, 20808.85, 22803.90) [kpc comoving]
#   host1 velocity = (-222.8, -334.5, -225.9) [km / s]
#   host1 axis ratios = (0.32, 0.36, 0.89)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0675:  using snapshot index = 551, redshift = 0.068
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_551.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337548 particles
#     star      (id = 4): 36557 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_551.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23562.90, 20825.60, 22815.17) [kpc comoving]
#   host1 velocity = (-223.1, -335.3, -226.9) [km / s]
#   host1 axis ratios = (0.29, 0.34, 0.86)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.07:  using snapshot index = 550, redshift = 0.070
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_550.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337581 particles
#     star      (id = 4): 36525 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_550.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23568.46, 20834.04, 22820.91) [kpc comoving]
#   host1 velocity = (-223.9, -335.3, -227.5) [km / s]
#   host1 axis ratios = (0.29, 0.33, 0.88)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0725:  using snapshot index = 549, redshift = 0.072
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_549.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337601 particles
#     star      (id = 4): 36505 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_549.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23574.14, 20842.48, 22826.64) [kpc comoving]
#   host1 velocity = (-224.6, -334.9, -228.2) [km / s]
#   host1 axis ratios = (0.30, 0.34, 0.88)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.075:  using snapshot index = 547, redshift = 0.075
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_547.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337620 particles
#     star      (id = 4): 36486 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_547.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23585.53, 20859.43, 22838.25) [kpc comoving]
#   host1 velocity = (-223.6, -333.1, -229.0) [km / s]
#   host1 axis ratios = (0.30, 0.36, 0.85)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0775:  using snapshot index = 546, redshift = 0.077
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_546.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337627 particles
#     star      (id = 4): 36479 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_546.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23591.20, 20867.88, 22844.08) [kpc comoving]
#   host1 velocity = (-222.8, -332.5, -228.8) [km / s]
#   host1 axis ratios = (0.31, 0.36, 0.87)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.08:  using snapshot index = 544, redshift = 0.081
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_544.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337658 particles
#     star      (id = 4): 36448 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_544.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23602.50, 20884.80, 22855.76) [kpc comoving]
#   host1 velocity = (-221.8, -332.0, -228.6) [km / s]
#   host1 axis ratios = (0.30, 0.35, 0.87)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.0825:  using snapshot index = 543, redshift = 0.083
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_543.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337688 particles
#     star      (id = 4): 36418 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_543.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23608.20, 20893.31, 22861.61) [kpc comoving]
#   host1 velocity = (-221.2, -331.9, -228.5) [km / s]
#   host1 axis ratios = (0.31, 0.35, 0.87)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.085:  using snapshot index = 542, redshift = 0.085
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_542.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22337735 particles
#     star      (id = 4): 36371 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_542.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
# ...
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.17500000000000002:  using snapshot index = 497, redshift = 0.176
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_497.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338427 particles
#     star      (id = 4): 35681 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_497.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23882.74, 21309.79, 23146.57) [kpc comoving]
#   host1 velocity = (-215.4, -328.7, -227.8) [km / s]
#   host1 axis ratios = (0.33, 0.36, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.1775:  using snapshot index = 496, redshift = 0.178
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_496.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338502 particles
#     star      (id = 4): 35606 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_496.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23889.04, 21319.31, 23153.26) [kpc comoving]
#   host1 velocity = (-214.9, -328.3, -227.8) [km / s]
#   host1 axis ratios = (0.31, 0.35, 0.89)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.18:  using snapshot index = 495, redshift = 0.180
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_495.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338728 particles
#     star      (id = 4): 35380 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_495.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23895.28, 21328.78, 23159.96) [kpc comoving]
#   host1 velocity = (-214.1, -328.2, -227.3) [km / s]
#   host1 axis ratios = (0.31, 0.35, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.1825:  using snapshot index = 494, redshift = 0.183
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_494.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338740 particles
#     star      (id = 4): 35368 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_494.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23901.49, 21338.33, 23166.64) [kpc comoving]
#   host1 velocity = (-214.0, -328.5, -226.5) [km / s]
#   host1 axis ratios = (0.32, 0.35, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.185:  using snapshot index = 493, redshift = 0.185
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_493.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338740 particles
#     star      (id = 4): 35368 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_493.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23907.70, 21347.91, 23173.24) [kpc comoving]
#   host1 velocity = (-214.2, -328.7, -225.8) [km / s]
#   host1 axis ratios = (0.31, 0.35, 0.89)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.1875:  using snapshot index = 492, redshift = 0.187
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_492.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338740 particles
#     star      (id = 4): 35368 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_492.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23913.95, 21357.53, 23179.85) [kpc comoving]
#   host1 velocity = (-214.1, -328.8, -225.4) [km / s]
#   host1 axis ratios = (0.31, 0.35, 0.88)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.19:  using snapshot index = 491, redshift = 0.189
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_491.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338744 particles
#     star      (id = 4): 35364 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_491.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23920.30, 21367.20, 23186.49) [kpc comoving]
#   host1 velocity = (-213.7, -328.9, -224.9) [km / s]
#   host1 axis ratios = (0.30, 0.34, 0.90)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.1925:  using snapshot index = 490, redshift = 0.192
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_490.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338763 particles
#     star      (id = 4): 35345 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_490.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23926.61, 21376.90, 23193.15) [kpc comoving]
#   host1 velocity = (-213.2, -329.1, -224.2) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.91)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.195:  using snapshot index = 489, redshift = 0.194
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_489.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338776 particles
#     star      (id = 4): 35332 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_489.hdf5
#
# ! cannot find MUSIC config file:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/track/host_coordinates.hdf5
#   host1 position = (23932.87, 21386.65, 23199.77) [kpc comoving]
#   host1 velocity = (-213.1, -329.4, -223.4) [km / s]
#   host1 axis ratios = (0.32, 0.34, 0.92)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/snapshot_times.txt
#
# * input redshift = 0.1975:  using snapshot index = 487, redshift = 0.198
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_487.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 22374200 particles
#     dark2     (id = 2): 19623813 particles
#     gas       (id = 0): 22338805 particles
#     star      (id = 4): 35303 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['dark', 'dark2', 'gas', 'star']
#
# * reading particles from:
#     data/groups/leauthaud/yluo42/FIRE/m11b_r2100/output/snapshot_487.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[285], line 6
#       4 alphas = []
#       5 for z in zees:
# ----> 6     particles = gizmo.io.Read.read_snapshots('all', 'redshift', z, gal)
#       8     mass_allstars = particles['star'].prop('mass')
#       9     age_allstars = particles['star'].prop('age')
#
# File ~/gizmo_analysis/gizmo_analysis/gizmo_io.py:1046, in ReadClass.read_snapshots(self, species, snapshot_value_kind, snapshot_values, simulation_directory, snapshot_directory, track_directory, simulation_name, properties, elements, particle_subsample_factor, separate_dark_lowres, sort_dark_by_id, convert_float32, host_number, assign_hosts, assign_hosts_rotation, assign_orbits, assign_formation_coordinates, assign_pointers, check_properties)
#    1041 header = self.read_header(
#    1042     simulation_directory, snapshot_directory, 'index', snapshot_index, simulation_name
#    1043 )
#    1045 # read particles from snapshot file[s]
# -> 1046 part = self._read_particles(
#    1047     simulation_directory,
#    1048     snapshot_directory,
#    1049     'index',
#    1050     snapshot_index,
#    1051     properties,
#    1052     elements,
#    1053     convert_float32,
#    1054     header,
#    1055 )
#    1057 # assign auxilliary information to particle dictionary class
#    1058 # store header dictionary
#    1059 part.info = header
#
# File ~/gizmo_analysis/gizmo_analysis/gizmo_io.py:1960, in ReadClass._read_particles(self, simulation_directory, snapshot_directory, snapshot_value_kind, snapshot_value, properties, elements, convert_float32, header)
#    1957                             else:
#    1958                                 prop_read_name = part_read[prop_read_name]
# -> 1960                             part[spec_name][prop_name][
#    1961                                 part_index_lo:part_index_hi, :
#    1962                             ] = prop_read_name
#    1964                 part_indices_lo[spec_i] = part_index_hi  # set indices for next file
#    1966 print()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/anaconda3/envs/breathingModes/lib/python3.11/site-packages/h5py/_hl/dataset.py:1063, in Dataset.__array__(self, dtype)
#    1060 if self.size == 0:
#    1061     return arr
# -> 1063 self.read_direct(arr)
#    1064 return arr
#
# File ~/anaconda3/envs/breathingModes/lib/python3.11/site-packages/h5py/_hl/dataset.py:1024, in Dataset.read_direct(self, dest, source_sel, dest_sel)
#    1021     dest_sel = sel.select(dest.shape, dest_sel)
#    1023 for mspace in dest_sel.broadcast(source_sel.array_shape):
# -> 1024     self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#
# KeyboardInterrupt:

# %%
plt.plot(alphas)
#plt.ylim([0,-1])

# %%
plt.plot(binedges[:-1], binmasses)
plt.plot(binedges[:10], binmasses[:10])
plt.xscale('log')
plt.yscale('log')

plt.xlim([0.5,50])

# %%
opt.curve_fit(powerlaw, binedges[:10], binmasses[:10])[0][0]
# Out:
# 0.04345944903158488

# %%
alphas
# Out:
# [0.1845611247892167, 5.831320626557968, 0.6417412210759714, 0.3135851016923462]

# %%
len(np.arangeg(0,0.25,0.0025))
